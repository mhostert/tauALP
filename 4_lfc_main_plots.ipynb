# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from alp import const
from alp import plot_tools as pt
from alp.models import ALP

# %% [markdown]
# # LFC

# %%
BP_NAME = 'LFC_universal_vMC'
c_lepton = np.diag([1, 1, 1])

fig, ax = pt.main_plot_LFC(BP_NAME, c_lepton, ymin=5e-6, ymax=1, xmin=2e-3, xmax=2, figsize=(5,6), loc='upper right', ncol=1, vlines=False, linewidth=0.1)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/darknews/lib/python3.11/site-packages/matplotlib/contour.py:1364: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.zmax = z.max().astype(float)
# /opt/homebrew/Caskroom/miniforge/base/envs/darknews/lib/python3.11/site-packages/matplotlib/contour.py:1365: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.zmin = z.min().astype(float)
# /opt/homebrew/Caskroom/miniforge/base/envs/darknews/lib/python3.11/site-packages/numpy/ma/core.py:2846: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data = np.array(data, dtype=dtype, copy=copy,
# /Users/mhostert/Repos/tau_LLPs/alp/plot_tools.py:1977: UserWarning: linewidths is ignored by contourf
#   ax.contourf(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 BP_NAME = 'LFC_universal_vMC'
#       2 c_lepton = np.diag([1, 1, 1])
# ----> 4 fig, ax = pt.main_plot_LFC(BP_NAME, c_lepton, ymin=5e-6, ymax=1, xmin=2e-3, xmax=2, figsize=(5,6), loc='upper right', ncol=1, vlines=False, linewidth=0.1)
#
# File ~/Repos/tau_LLPs/alp/plot_tools.py:841, in main_plot_LFC(BP_NAME, c_lepton, fa_power, plot_DUNEs, figsize, ymax, ymin, xmin, xmax, ncol, loc, yscale, xscale, legend, name_modifier, vlines, linewidth)
#     838 name = BP_NAME
#     840 Nsig = 2.3
# --> 841 X, Y, Z = np.load(f"data/CHARM_rates_{name}.npy", allow_pickle=True)
#     842 c = ax.contourf(
#     843     X,
#     844     Y**fa_power,
#    (...)
#     849     zorder=1.2,
#     850 )
#     851 _ = ax.contour(
#     852     X,
#     853     Y**fa_power,
#    (...)
#     860     zorder=2,
#     861 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/darknews/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:455, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453     own_fid = False
#     454 else:
# --> 455     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     456     own_fid = True
#     458 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/CHARM_rates_LFC_universal_vMC.npy'

# %%
BP_NAME = 'LFC_universal_jul10'
c_lepton = np.diag([1, 1, 1])
pt.main_plot_LFC(BP_NAME, c_lepton, ymin=5e-6, ymax=1, xmin=2e-3, xmax=2, figsize=(5,6), loc='upper right', ncol=1, vlines=False, linewidth=0.1)

BP_NAME = 'LFC_etau_jul10'
c_lepton = np.diag([1, 0, 1])
pt.main_plot_LFC(BP_NAME, c_lepton, ymin=5e-6, ymax=1, xmin=2e-3, xmax=2, figsize=(5,6), loc='upper right', ncol=1, vlines=False, linewidth=0.1)

BP_NAME = 'LFC_tauphilic_jul10'
c_lepton = np.diag([0, 0, 1])
pt.main_plot_LFC(BP_NAME, c_lepton, ymin=1e-4, ymax=10, xmin=2e-3, xmax=2, figsize=(5,6), loc='lower left', ncol=1, vlines=False, linewidth=0.1)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/darknews/lib/python3.11/site-packages/matplotlib/contour.py:1364: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.zmax = z.max().astype(float)
# /opt/homebrew/Caskroom/miniforge/base/envs/darknews/lib/python3.11/site-packages/matplotlib/contour.py:1365: ComplexWarning: Casting complex values to real discards the imaginary part
#   self.zmin = z.min().astype(float)
# /opt/homebrew/Caskroom/miniforge/base/envs/darknews/lib/python3.11/site-packages/numpy/ma/core.py:2846: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data = np.array(data, dtype=dtype, copy=copy,
# /Users/mhostert/Repos/tau_LLPs/alp/plot_tools.py:1977: UserWarning: linewidths is ignored by contourf
#   ax.contourf(
# (<Figure size 500x600 with 1 Axes>,
#  <Axes: title={'center': '{\\bf LFC $\\tau$-philic} $\\,\\,\\vert\\,\\,$$g_{e e} = g_{\\mu \\mu} = 0$ $\\,\\,\\vert\\,\\,$ $g_{\\tau \\tau} = 1$'}, xlabel='$m_a$ [GeV]', ylabel='$f_a^{-1}$ [GeV$^{-1}$]'>)

# %% [markdown]
# ## Exploring window above dimuon threshold

# %%
from alp import exp
from alp.exp_dicts import EXPERIMENTS

SPS_files = "tau_events/df_400GeV.parquet"  # In-house MC
SHIP = exp.Experiment(SPS_files, exp_dic=EXPERIMENTS['SHiP'])

ma_vals= np.append(np.linspace(0.2, 0.22, 50), np.linspace(0.21, 0.212, 20))
rates = []
for ma in ma_vals:
    alp = ALP(ma, 4e4, c_lepton=np.diag([1,1,1]))
    rates.append(SHIP.get_event_rate(alp))
rates = np.array(rates)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       9 for ma in ma_vals:
#      10     alp = ALP(ma, 4e4, c_lepton=np.diag([1,1,1]))
# ---> 11     rates.append(SHIP.get_event_rate(alp))
#      12 rates = np.array(rates)
#
# File ~/Repos/tau_LLPs/alp/exp.py:632, in Experiment.get_event_rate(self, alp, selection, generate_events)
#     623 def get_event_rate(self, alp, selection=True, generate_events=True):
#     624
#     625     # self.dPhidp, self.palp = self.get_alp_momentum_spectrum(
#    (...)
#     629     # self.dp = np.diff(self.palp)
#     630     # self.pc = self.palp[:-1] + self.dp / 2
#     631     if generate_events:
# --> 632         self.get_alps_in_acceptance(generate_events=generate_events, alp=alp)
#     634     self.flux = self.norm * self.weights[self.mask_alp_in_acc]
#     635     self.p4_alp_in_acc = self.p4_alp[self.mask_alp_in_acc]
#
# File ~/Repos/tau_LLPs/alp/exp.py:512, in Experiment.get_alps_in_acceptance(self, generate_events, alp)
#     509 def get_alps_in_acceptance(self, generate_events=True, alp=None):
#     511     if generate_events or hasattr(self, "p4_alp") is False:
# --> 512         self.get_alp_events(alp=alp)
#     514     # NOTE: Selection of events in a square assuming a cuboid
#     515     if hasattr(self, "R"):
#
# File ~/Repos/tau_LLPs/alp/exp.py:439, in Experiment.get_alp_events(self, alp)
#     433 for decay_channel in self.final_states:
#     435     if (
#     436         alp.tau_BR(prod_channel) > 0
#     437         and vars(alp)[f"BR_a_to_{decay_channel}"] > 0
#     438     ):
# --> 439         p1, p2, weights = self.generate_alp_events(
#     440             alp, prod_channel, decay_channel
#     441         )
#     442         p1_list.append(p1)
#     443         p2_list.append(p2)
#
# File ~/Repos/tau_LLPs/alp/exp.py:406, in Experiment.generate_alp_events(self, alp, production_channel, decay_channel)
#     402     self.tau_BRs[production_channel] = alp.tau_BR(production_channel)
#     403 else:
#     404     # 3 or 4-body, so perform a MC numerical integral using our own samples
#     405     self.tau_BRs[production_channel] = np.sum(
# --> 406         alp.tau_diff_BR(ECM_alp, production_channel) / self.nevents
#     407     ) * (alp.Ea_max[production_channel] - alp.Ea_min[production_channel])
#     409 self.weights = self.tau_weights * self.tau_BRs[production_channel]
#     411 return self.p4_1, self.p4_2, self.weights
#
# File ~/Repos/tau_LLPs/alp/models.py:312, in ALP.tau_diff_BR(self, Ea, production_channel)
#     310     return self.diff_BR_tau_to_nu_nu_e_a(Ea)
#     311 elif production_channel == "tau>nu+nu+mu+a":
# --> 312     return self.diff_BR_tau_to_nu_nu_mu_a(Ea)
#     313 else:
#     314     raise ValueError(f"Unknown production channel {production_channel}")
#
# File ~/Repos/tau_LLPs/alp/models.py:447, in ALP.diff_BR_tau_to_nu_nu_mu_a(self, Ea)
#     437 """Differential decay rate for tau -> rho nu a"""
#     438 mtau_barSQR = const.m_tau**2 + self.m_a**2 - 2 * const.m_tau * Ea
#     439 dGammadE = (
#     440     self.c_lepton[2, 2] ** 2
#     441     * const.Gf**2
#     442     * const.m_tau**2
#     443     * mtau_barSQR
#     444     / 1536
#     445     / np.pi**5
#     446     / self.f_a**2
# --> 447     * Iv_mvv_integral(Ea, self.m_a, mlep=const.m_mu)
#     448     * (
#     449         1
#     450         - self.m_a**2
#     451         * (const.m_tau**2 + mtau_barSQR)
#     452         / (const.m_tau**2 - mtau_barSQR) ** 2
#     453     )
#     454     * ps.v_2body(const.m_tau, np.sqrt(mtau_barSQR), self.m_a)
#     455 )
#     456 return (
#     457     dGammadE
#     458     * (Ea > self.Ea_min["tau>nu+nu+mu+a"])
#     459     * (Ea < self.Ea_max["tau>nu+nu+mu+a"])
#     460 ) / Gamma_tau
#
# File ~/Repos/tau_LLPs/alp/models.py:949, in Iv_mvv_integral(Ea, ma, mlep, mtau)
#     926 def Iv_mvv_integral(Ea, ma, mlep, mtau=const.m_tau):
#     927     """Integral for the visible decay width of ALP decays
#     928
#     929     Integral of (I * v) over mvvSQR
#    (...)
#     940
#     941     """
#     943     return (
#     944         Power(ma, 2)
#     945         - 8 * Power(mlep, 2)
#     946         - 2 * Ea * mtau
#     947         + Power(mtau, 2)
#     948         - Power(mlep, 8) / Power(Power(ma, 2) - 2 * Ea * mtau + Power(mtau, 2), 3)
# --> 949         + (8 * Power(mlep, 6)) / Power(Power(ma, 2) - 2 * Ea * mtau + Power(mtau, 2), 2)
#     950     ) / 2.0 + (
#     951         6
#     952         * Power(mlep, 4)
#     953         * Log((Power(ma, 2) - 2 * Ea * mtau + Power(mtau, 2)) / Power(mlep, 2))
#     954     ) / (
#     955         Power(ma, 2) + mtau * (-2 * Ea + mtau)
#     956     )
#
# File ~/Repos/tau_LLPs/alp/models.py:914, in Power(x, y)
#     910     """min of s12 = (P - p3)^2 for given M, m1, m2, m3"""
#     911     return (m1 + m2) ** 2
# --> 914 def Power(x, y):
#     915     return x**y
#     918 def Log(x):
#
# KeyboardInterrupt:

# %%
rates = rates[np.argsort(ma_vals)]
ma_vals = ma_vals[np.argsort(ma_vals)]
fig, ax = pt.std_fig()
alps = ALP(ma_vals, 4e4, c_lepton=np.diag([1,1,1]))
ax.plot(1e3*(ma_vals - 2*const.m_mu), rates, color='steelblue')
ax2 = ax.twinx()
ax2.plot(1e3*(ma_vals - 2*const.m_mu), 1e-2*const.get_decay_rate_in_cm(alps.Gamma_a), color="firebrick", linestyle="--")
ax2.set_ylabel(r"$c \tau_a$/m", color="firebrick")
# plt.grid()
ax.set_yscale("log")
ax2.set_yscale("log")
# ax2.set_xscale("log")
ax.set_ylabel("Event rate", color="steelblue")
ax.set_xlabel("$(m_a - 2 m_\mu)$/MeV")
ax.set_title("SHiP event rate ($f_a = 10^{4}$ GeV)", fontsize=11)
ax.vlines(x=0, ymin=0, ymax=1e2, color="black", linestyle=(1,(5,1)), lw=0.5)
ax.set_xlim(-3, 3)
# ax.set_xlim(-10, 10)
fig.savefig("plots/ship_event_rate_around_threshold.pdf", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 rates = rates[np.argsort(ma_vals)]
#       2 ma_vals = ma_vals[np.argsort(ma_vals)]
#       3 fig, ax = pt.std_fig()
#
# NameError: name 'rates' is not defined
